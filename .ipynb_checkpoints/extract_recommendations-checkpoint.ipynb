# %% [markdown]
# ## Extraction of Safety Recommendations from

# %%
#encoding:utf-8
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
from string import punctuation
from collections import Counter
import re
df=pd.read_excel("SafeCity - Dashboard - Overall - Updated - April 2018_edited.xlsx")

#print df
#df.columns

# %%
df.shape
# Out:
# (10356, 67)

# %%
for i,name in enumerate(df.columns):
    print i,name
list(df)
data=df[["INCIDENT ID","INCIDENT TITLE","DESCRIPTION","LATITUDE","LONGITUDE","Location","City Code"]]
len(data)
# Out:
# 0 INCIDENT ID
# 1 INCIDENT TITLE
# 2 DATE
# 3 YEAR
# 4 MONTH
# 5 WEEK OF THE MONTH
# 6 DAY
# 7 TIME
# 8 QUARTER OF THE DAY
# 9 HOUR OF THE DAY
# 10 MINUTE OF THE HOUR
# 11 DESCRIPTION
# 12 Catcalls/Whistles
# 13 Commenting
# 14 Sexual Invites
# 15 Ogling/Facial Expressions/Staring
# 16 Taking Pictures
# 17 Indecent Exposure
# 18 Touching /Groping
# 19 Stalking
# 20 Rape / Sexual Assault
# 21 Poor / No Street Lighting
# 22 Chain Snatching
# 23 North East India Report
# 24 Others
# 25 VERBAL ABUSE
# 26 NON-VERBAL ABUSE
# 27 PHYSICAL ABUSE
# 28 SERIOUS PHYSICAL ABUSE
# 29 OTHER ABUSE
# 30 Location
# 31 Country Code
# 32 City Code
# 33 Area Code
# 34 Locality Code
# 35 LATITUDE
# 36 LONGITUDE
# 37 Please Check
# 38 More Info
# 39 Flag
# 40 * Car *
# 41 * Train *
# 42 * Bus *
# 43 * Metro *
# 44 * Auto *
# 45 Taxi
# 46 Car
# 47 Train
# 48 Bus
# 49 Metro
# 50 Auto
# 51 * Rail *
# 52 Rail
# 53 Airport
# 54 Road
# 55 Travel
# 56 Passenger
# 57 Rickshaw
# 58 Driver
# 59 Conductor
# ...

# %%
df=df[["INCIDENT ID","INCIDENT TITLE","DESCRIPTION","LATITUDE","LONGITUDE","Location","City Code"]]

list(df)
df.isna().sum()
#only DESCRIPTION column contains NAs hence can omit all rows that contain NAs in the dataframe
df=df.dropna(axis=0,how='any') 
df.isna().sum()
#now all values in DESCRIPTION column are unicode type

#convert to lower case
df.DESCRIPTION=map(lambda x: x.lower(),df.DESCRIPTION)

import string
from nltk import word_tokenize
import re
a=0
for text in df.DESCRIPTION:
    #print text
    #print "##############"
    #print type(text)
    text=text.encode('utf-8')
    if type(text)=='unicode':
        a=a+1
        text=text.encode('utf-8')
        text=re.sub('[^A-Za-z0-9]+', ' ', text)
        
   # print text
recommendations=[]

lat=[]
lon=[]
print len(df),a
row=0
for sent in df.DESCRIPTION:
    stop=[',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}','$']

    sent = ''.join(ch for ch in sent if ch not in stop)
    #print sent
keywords=["no light","poor light","poorly lit","not safe","take care","not lit","unsafe","dangerous","bad light","patrol", 
         "avoid","whenever"]
for sent in df.DESCRIPTION:
    sentences=sent.split('.')
    s=""
    for sentence in sentences:
        
        sentence=sentence.strip('"')
        if any(x in sentence for x in keywords):
            
            
            #print sentence
            #print "###"
            a+=1
            if len(s)>0: s=s+","
            s=s+(sentence.encode('utf-8'))
            s=s.replace('\n','')
            #print s
       
    

    if len(s)>0:

        recommendations.append(s)#removing \n etc

        lat.append(df.iloc[row,2])
        lon.append(df.iloc[row,3])
    row+=1
#print (recommendations)
print len(recommendations),len(lat),len(lon)
recom=pd.DataFrame()

recom["RECOMMENDATION"]=recommendations
print recommendations[1]

recom["LATITUDE"]=lat
recom["LONGITUDE"]=lon
print recom.head
#recom.to_csv("Recommendations_SafecityApril2018.csv",index=None)
        
            
            
print a


#print "i=",i
##removing punctuations using string.translate()
#table = string.maketrans("","") 

#for text in df.DESCRIPTION:
  #  text=str(text)
   # text=text.translate(table,string.punctuation)
   # print text
# Out:
# 10269 0
# 314 314 314
#  this guy used to call her often whenever she is seen in terrace or outside her house
# <bound method DataFrame.head of                                         RECOMMENDATION  \
# 0     i would always try to avoid him, but never me...
# 1     this guy used to call her often whenever she ...
# 2    it's the most horrible place ever and i think ...
# 3    in sarjapura road signal bus stop ,bangalore, ...
# 4    as i was coming back from jamia millia,i was w...
# 5    in sarjapura road signal bus stop ,bangalore, ...
# 6    i had just come to chennai and was sitting at ...
# 7     stations are dark, no lights inside the platform
# 8     please avoid walking on the pavements here if...
# 9     these areas are *to be avoided* places especi...
# 10   unsafe sub way, poorly lit light without any s...
# 11   it is properly lighted, it is extremely busy, ...
# 12    the area around nageshwara park is also not s...
# ...

# %%
####delete - college catcalls, catcalling, she feels unsafe, delhi most dangerous, i felt unsafe, i feel unsafe

# %%
df.dtypes
x=map(lambda x:type(x),df.DESCRIPTION)

#printing unique values in x
print set(x)
#both unicode and float objects seem to be present

import nltk
from nltk import ne_chunk, pos_tag, word_tokenize
from nltk.tree import Tree
# Out:
# set([<type 'unicode'>])

# %%
import nltk
from nltk import ne_chunk, pos_tag, word_tokenize
from nltk.tree import Tree
# Out:
#   File "<ipython-input-8-71999e46a3dd>", line 13
#     type(text) is 'str':
#                        ^
# SyntaxError: invalid syntax

# %%
#if POS tagged ( "LOCATION" ) comes before "unsafe" or "poor lighting" etc, include that in the extracted text. 
#HOW WILL YOU TAG THE COMMENTS TO THE PLACES ON THE MAP?


df = df.reset_index(drop=True)

df_edited=pd.read_csv("Combined_RecommendationsSafecity.csv")
print len(df_edited)

#print len(data),len(data["INCIDENT TITLE"])
#print (data["INCIDENT TITLE"])
#df_edited["INCIDENT TYPE"]=[]
print data.head
# Out:
# 105
# <bound method DataFrame.head of        INCIDENT ID                                     INCIDENT TITLE  \
# 0              256                            Inappropriate behaviour
# 1              255                                 indecent behaviour
# 2             1723         Friend (??) helping an eveteaser harass me
# 3             1068                             Abuse by family member
# 4             4018                      Abused when I was 7 years old
# 5             1054                                  Indecent exposure
# 6             4084                                Groping in the auto
# 7             3013                                   When I was young
# 8             4188                           Groping while in the bus
# 9             5981                                       Family Issue
# 10            3038                                            Staring
# 11            4141                                harassment in delhi
# ...

# %%
# print df
typeof=[]
address=[]
code_city=[]
n=0
print len(df_edited)
#print data["INCIDENT TITLE"]
for rec in df_edited.RECOMMENDATION:
    
    if  len(df[df['DESCRIPTION'].str.contains(rec)])>0:
        
        
        x= (df[df['DESCRIPTION'].str.contains(rec)]).index.values[0]
#         typeof.append(df.iloc[x]["INCIDENT TITLE"])
        address.append(df.iloc[x]["Location"])
        code_city.append(df.iloc[x]["City Code"])
    else:
#         typeof.append("Not Available")
        address.append("Not Available")
        code_city.append("Not Available")
# print len(typeof)
# print code_city,address
# df_edited["INCIDENT TITLE"]=typeof
df_edited["LOCATION"]=address
df_edited["CITY CODE"]=code_city
# df_edited=df_edited.drop_duplicates(subset=['RECOMMENDATION'])
print len(df_edited)
df_edited.to_csv("Recommendations_Safecity2018_Titled.csv",index=None)
# Out:
# 105
# C:\Users\Parvathy.Sarat\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:10: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   # Remove the CWD from sys.path while we load stuff.
# 105

# %%
# print len(typeof)
# df_edited["INCIDENT TYPE"]=typeof
print list(df_edited)
print df_edited
# Out:
# ['RECOMMENDATION', 'LATITUDE', 'LONGITUDE', 'INCIDENT TITLE', 'LOCATION', 'CITY CODE']
#                                        RECOMMENDATION   LATITUDE   LONGITUDE  \
# 0   it's the most horrible place ever and i think ...  19.202805   72.852436
# 1   in sarjapura road signal bus stop ,bangalore, ...  12.971599   77.594563
# 2    stations are dark, no lights inside the platform  18.961490   72.839962
# 3   unsafe sub way, poorly lit light without any s...  13.026604   77.585916
# 4   it is properly lighted, it is extremely busy, ...  13.060422   80.249583
# 5    the area around nageshwara park is also not s...  13.033611   80.268611
# 6   8:30-9 pm onwards, this street is full of rick...  19.129738   72.829155
# 7   i used to work down the road opp infinity mall...  19.129738   72.829155
# 8   these are the one sentiment echoed by all the ...  19.149901   72.931134
# 9   i ask my husband to accompany me as the approa...  19.046840   72.862964
# ...

# %%
import numpy as np
df_old=pd.read_csv("Recommendations_Safecity2018_Titled.csv")
print list(df_old)
df_old=df_old.drop_duplicates(subset=['RECOMMENDATION'])
print len(df_old)
print len(df_edited)
list(df_old)
# Out:
# ['RECOMMENDATION', 'LATITUDE', 'LONGITUDE', 'INCIDENT TITLE', 'LOCATION', 'CITY CODE']
# 80
# 80
# ['RECOMMENDATION',
#  'LATITUDE',
#  'LONGITUDE',
#  'INCIDENT TITLE',
#  'LOCATION',
#  'CITY CODE']

# %%
# new_df = pd.merge(df_old, df_edited)
# len(new_df)
# pd.DataFrame.concat([df1,df2], axis=0)

for col in df_edited:
    if col=='RECOMMENDATION':
        recom_=list(df_edited[col])+list(df_old[col])
    if col=='LATITUDE':
        lat_=list(df_edited[col])+list(df_old[col])
    if col=='LONGITUDE':
        lon_=list(df_edited[col])+list(df_old[col])
    if col=='INCIDENT TITLE':
        title_=list(df_edited[col])+list(df_old[col])

new_df=pd.DataFrame()

new_df["RECOMMENDATION"]=recom_

new_df["LATITUDE"]=lat_
new_df["LONGITUDE"]=lon_
new_df["INCIDENT TITLE"]=title_
len(new_df)
new_df=new_df.drop_duplicates()

#resetting index after dropping columns
new_df=new_df.reset_index(drop=True)
len(new_df)
new_df.to_csv("Combined_RecommendationsSafecity.csv",index=False)

# %%
##GROUPING BY CITY CODE

df=pd.read_csv("Recommendations_Safecity2018_Titled.csv")
df_new=pd.DataFrame(columns=list(df_edited))

df_new=(df[df["CITY CODE"]==0])
df_new=pd.concat([df_new,df[df["CITY CODE"]==1]],axis=0)
df_new=pd.concat([df_new,df[df["CITY CODE"]==2]],axis=0)
df_new=pd.concat([df_new,df[df["CITY CODE"]==3]],axis=0)

print df_new

# df=df.groupby('CITY CODE',as_index=False).sum()
# # df=df.sum().reset_index()
# # print df.head(3)
# # print df.describe()
# df_new=pd.DataFrame(columns=list(df_edited))
# for key, item in df:
#     df_new.append(df.get_group(key))
#     print (df.get_group(key))
#     print item
df_new.to_csv("Groupedby_CityCode.csv",index=False)
# print df_new
# Out:
#                                         RECOMMENDATION   LATITUDE   LONGITUDE  \
# 1    in sarjapura road signal bus stop ,bangalore, ...  12.971599   77.594563
# 3    unsafe sub way, poorly lit light without any s...  13.026604   77.585916
# 4    it is properly lighted, it is extremely busy, ...  13.060422   80.249583
# 5     the area around nageshwara park is also not s...  13.033611   80.268611
# 18   according to me the most unsafe place in delhi...  20.429047   80.149403
# 19   at night, iwas  passing through moti bagh, i f...  20.429047   80.149403
# 22   at night ,,what everytime happens there,,,,hig...  20.429047   80.149403
# 30   after 8-9 pm, outer area of greater noida is v...  28.474388   77.503990
# 31            buses heading to this place are not safe  28.577380   77.314494
# 50   roads and inner road (subways) of dhobichaur a...  27.713605   85.306421
# 51   the place is surronded by goons and very unsaf...  23.165196   79.950747
# ...
